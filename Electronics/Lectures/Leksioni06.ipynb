# %% [markdown]
# # **Diodat**
#
# ## **Historku: Diodat e Vakumit**
#
# Diodat me vakum (shpesh të quajtura edhe “valvola” në gjuhën popullore) janë paraardhëset e para teknologjike të diodave gjysmëpërçuese që njohim sot. Ato u zhvilluan rreth fillimit të shekullit XX dhe ishin thelbësore në elektronikën e hershme, para epokës së transistorëve. Më poshtë një pasqyrë e shkurtër:
#
# <figure>
# <img src="figs/lec6/Vacuum_diode.svg" alt="Vdiode" width="30%" style="background-color:#fff;" > <img src="figs/lec6/Diode-lamp_al.svg" alt="Vdiode" width="30%" style="background-color:#fff;" > <img src="figs/lec6/vacuum_tube.png" alt="Vdiode" width="30%">
#    <figcaption> Simboli, skema dhe diode reale. </figcaption>
# </figure>
#
#
# 1. **Struktura Themelore:**
#    - Në thelb, një diodë me vakum përbëhet nga një **katodë** (e nxehtë) dhe një **anodë** (pllakë metalike) brenda një vakumi hermetik.
#    - Kur katoda nxehet (zakonisht me një filament), ajo lëshon elektrone (efekti termoelektronik). Ato elektrone mund të lëvizin drejt anodes nëse ajo është në potencial pozitiv në krahasim me katodën, duke mundësuar rrjedhjen e rrymës vetëm në një drejtim.
#
# 2. **Parimi i Funksionimit:**
#    - Në rast se aplikohet një diferencë potenciale e drejtë (+ në anodë dhe - në katodë), elektronet e prodhuara në katodë mund të lëvizin pa fërkim/rezistencë në tub drejt anodes për shkak të mungesës së molekulave/atomeve (vakumit).
#    - Në se aplikohet një diferencë potencial në kahun e kundërt (- në anodë dhe + në katodë), fusha elektrike brënda tubit pengon elektronet të lëvizin drejt anodës, si rrjedhojë bllokohet rrjedhja e rrymës.
#
# 3. **Rëndësia Historike:**
#    - Dioda me vakum ishte komponenti i parë që bënte drejtimin e rrymës (rectification) për sinjale AC (rryma elektrike alternative).
#    - Ajo hapi rrugën për zbulimin e tubave të tjerë elektronikë, si triodat, tetrodat, pentodat, etj., të cilat u përdorën gjerësisht në radiokomunikacion, amplifikim, dhe më vonë në sistemet televizive.
#
# 4. **Kufizimet Kryesore:**
#    - Konsum i madh energjie, pasi filamenti duhej të nxehej vazhdimisht.
#    - Pajisje të brishta dhe me dimensione relativisht të mëdha.
#    - U zëvendësuan kryesisht nga diodat gjysmëpërçuese, që janë më efikase, më të vogla dhe nuk kanë nevojë për ngrohje.
#
# <br>
# <br>
#
#
# ## **Diodat Gjysmëpërçuese**
#
# Le të hyjmë tani në **diodat gjysmëpërçuese** dhe t’i hedhim një vështrim bazave të tyre. Në këtë pikë, është e rëndësishme të kuptojmë njëherazi si përgatitet materiali gjysmëpërçues (silici, germaniumi) dhe si formohet kalimi p-n. Kjo do të na mundësojë të shpjegojmë funksionimin kryesor të diodës si “valvul elektrike” njëdrejtimëshe.
#
#
# ## 1. Struktura e Materialit Gjysmëpërçues
#
# - **Gjysmëpërçuesit e pastër (intrinsic)**: Në kushtet e temperaturës së dhomës, silici ose germaniumi ka një numër mjaft të vogël elektronësh (dhe vrimash) të lirë. Përcjellshmëria e tyre është e kufizuar.
# - **Gjysmëpërçuesit të dopuar (extrinsic)**: Për ta rritur përcjellshmërinë, në strukturën e silicit shtohen atome “papastërtish”:
#   - **Tipi n**: Doping me elementë pentavalentë (p.sh. fosfor). Këta atome sjellin **elektrone shtesë**.
#   - **Tipi p**: Doping me elementë trivalentë (p.sh. bor). Këta atome krijojnë **vrima shtesë** (mungesë e një elektroni).
#
# <img src="figs/lec6/conductance.png" alt="Vdiode" width="50%" style="background-color:#fff;" >
# <img src="figs/lec6/e_v_analogy.png" alt="Vdiode" width="50%" style="background-color:#fff;" >
#
#
# ## 2. Formimi i Kalimit p-n
#
# Në momentin kur **dy rajone** (n dhe p) bashkohen:
#
# 1. **Difuzioni i transportuesve**: Elektronet nga rajoni n tentojnë të kalojnë në rajonin p, ndërsa vrimat nga rajoni p shkojnë drejt rajonit n.
# 2. **Zonë e varfërimit (Depletion Region)**: Krijohet një zonë e mesme ku elektronet dhe vrimat kanë “neutralizuar” njëra-tjetrën, duke lënë pas jone fikse të ngarkuara (negative në anën p dhe pozitive në anën n).
# 3. **Tensioni ndërtues (Built-in Voltage)**: Zona e varfërimit shoqërohet me një diferencë potenciali të brëndshme, e cila pengon difuzionin e bartësave më tej. Ky tension është rreth 0.6-0.7V për diodën e silicit dhe rreth 0.3V për atë të germaniumit.
#
#
#
# ## 3. Karakteristika e Polaritetit të Tensionit (Forward/Reverse Bias)
#
# - **Polarizimi i drejtë (Forward Bias)**: Anoda (p) lidhet në potencial pozitiv, katoda (n) në negativ. Kjo redukton barrierën e zonës së varfërimit, duke lejuar rrymën të rrjedhë.
# - **Polarizimi i kundërt (Reverse Bias)**: Anoda (p) lidhet në potencial negativ, katoda (n) në pozitiv. Zona e varfërimit zgjerohet, duke penguar rrjedhjen e rrymës (përveç një rryme shumë të vogël inverse).
#
#
# <img src="figs/lec6/pn_forward.png" alt="Vdiode" width="30%" style="background-color:#fff;" > <img src="figs/lec6/pn_reverse.png" alt="Vdiode" width="30%" style="background-color:#fff;" >
#
#
#
# ## 4. Karakteristika V–I
#
# Për një diodë tipike silici, kur aplikojmë **tension përpara**:
#
# - Deri në rreth **0.7 V** (për silic) rryma është mjaft e vogël.
# - Mbi këtë prag (tensioni i barrierës për silic ~0.7 V), rryma rritet shpejt (ekspotencialisht).
#
# Në **polarizim të kundërt**, rryma mbetet pothuajse konstante dhe shumë e vogël (rryma e ngopjes), derisa mund të arrihet një pikë “thyerjeje” (breakdown) në tensione të larta ku dioda mund të dëmtohet (ose të përdoret qëllimisht, si te diodat Zener).
#
# <img src="figs/lec6/diode_analog.png" alt="Vdiode" width="100%" style="background-color:#fff;" >
# <img src="figs/lec6/zener_analog.png" alt="Vdiode" width="100%" style="background-color:#fff;" >

# %% [markdown]
# <br>
# <br>
#
# # **Diodat Gjysmëpërçuese**
#
# ## 1. Parimi Themelor i Diodës
#
# Një **diodë gjysmëpërçuese** është një komponent elektronik që **lejon rrymën të rrjedhë në një drejtim**, por e bllokon në drejtimin tjetër. Kjo sillet për shkak të **strukturës p-n**, e cila krijon një **zonë varfërimi** (depletion zone) ku nuk ka transportues të lirë ngarkese.
#
# ### Struktura p-n
# - Rajoni **n** ka elektrone të tepërta (doping me elementë pentavalentë).
# - Rajoni **p** ka vrima të tepërta (doping me elementë trivalentë).
# - Kur bashkohen, elektronet dhe vrimat difuzojnë dhe krijojnë një **zonë pa ngarkesa të lira**, e cila paraqet një **barrierë potenciali** (~0.6–0.7 V për silic).
#
#
# ## 2. Kurba V–I dhe **Ligji Shockley**
#
# #### Lidhje e Drejtë e Diodës ($V>0$)
#
# Sic dhe e pame me lart, aplikimi i një tensioni të drejtë mbi diodë krijon një fushë elektrike brënda që kundërshton ate të zonës së varfëruar në kalimin p-n. Kjo ngushton zonën e varfëruar dhe lehtëson rrjedhjen e rrymës së difuzionit që ishte bllokuar me parë. Observohet se rryma që rrjedh në diodë rritet **eksponencialisht** me tensionin e aplikuar dhe përshkruhet nga ligji Shockley që shkruhet:
# $$
# I(V) = I_S \left(e^{\frac{V}{nV_T}} - 1\right)
# $$
#
# ku:
# - $I_S$ është **rryma e ngopjes e lidhjes së kundërt (reverse-bias saturation or leakage current)**, shumë e vogël, < 1 nA.
# - $n$ është **faktori idealitetit ose faktori i kualitetit apo konstantja materialit** dhe merr vlera tipikisht midis 1 dhe 2 (mund të jetë edhe më e madhe në varësi të fabrikimit dhe materialit). Diodat ideale kanë $n= 1$.
# - $V_T = \frac{kT}{q} \approx 25 mV$ në temperaturë dhome.
#
# #### Lidhje e Kundërt e Diodës ($V<0$)
#
# Lidhja me polaritet të kundërt shkakton një fushë të brëndeshme që i mbivendoset asaj të zonës së varfëruar të kalimit p-n duke rritur gjërësinë e kësaj të fundit. Kjo pengon edhe me shumë rrjedhjen e rrymës përvec rrymes së dobët të ngopjes $I_S$.
#
#
# ### **Limitimet e Ligji Shockley**
#
# 1. **Rezistenca e brendshme** shkakton një “ngopje” të rritjes së rrymës në karakteristikën $I$–$V$ të një diode reale për vlera të larta të tensionit të drejtë (forward biased).
#    - Ligji i Shockley **nuk e modelon këtë efekt**, por mund të përfshihet duke shtuar një **rezistencë në seri** me diodën.
#
# 2. **Rajoni i prishjes së qëndrueshmërisë (Breakdown Region) në polarizim të kundërt** (veçanërisht i rëndësishëm për diodat Zener) **nuk përfshihet** në modelin e Shockley.
#
# 3. **Ligji i Shockley nuk përfshin zhurmat elektronike**, si:
#    - **Zhurma Johnson–Nyquist** (zhurma termale) që vjen nga rezistenca e brendshme,
#    - **Zhurma "Shot"** (shot noise) që lidhet me transportin diskret të ngarkesave.
#
# 4. **Ligji i Shockley përshkruan vetëm gjendjen e qëndrueshme (steady-state)** të rrymës.
#    - Ai **nuk merr parasysh sjelljen kalimtare (transient response)** të diodës, si:
#      - **Kapaciteti i kalimit p-n dhe difuzionit**,
#      - **Koha e rikuperimit në polarizim të kundërt (reverse recovery time)**.
#
#
# ### **Zona e Prishjes së Qëndrueshmërisë (Breakdown Region)**
#
# Për tensione të kundërta mjaftueshmërisht të mëdha, dioda pëson:
# - **Efektin Zener** (Zener Breakdown) - për dioda shumë të dopuara, për shkak të efektit të tunelimit kuantik.
# - **Efektit Ortek** (Avalanche Breakdown) - për dioda pak të dopuara, për shkak të shumëfishimit të mbartësave të lirë të ngargesës.
#
# <div style="border:5px solid #0a0; background-color:#ca0; color:#003; border-radius: 15px; padding: 10px;">
#
# **Shënim:** Diodat nuk shkatarrohen nga efekti Ortek apo Zener. Ato shkatarrohen vetëm nga efekti termik kur mbi to kalon rrymë e madhe (ose tensione të medha të drejta ose të kundërta) që shkakton nxehjen dhe më pas shkatarrimin e kalimit p-n.
#
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# Parametra të diodës
Is = 1e-12       # Rryma e ngopjes (A)
n = 1.5          # Faktori i idealitetit
VT = 0.02585     # Tensioni termik (V)
Rs = 10          # Rezistenca serike (Ohm)
Vz = -0.7        # Tensioni i prishjes për breakdown
Iz_max = 50e-3   # Rryma maksimale në prishje (A)

# Vargu i tensioneve
V = np.linspace(-1.0, 1.5, 1000)

# 1. Shockley ideal
def I_shockley(V):
    return Is * (np.exp(V / (n * VT)) - 1)

# 2. Modeli me Rs duke përdorur fsolve për zgjidhje të saktë
def I_with_Rs(V, Rs=10):
    I = np.zeros_like(V)
    for i, v in enumerate(V):
        if v < 0:
            I[i] = I_shockley(v)  # përdorim v si float
        else:
            def diode_eq(I_val, V_appl):
                return I_val * Rs + n * VT * np.log(I_val / Is + 1) - V_appl
            I0 = I[i - 1] if i > 0 else 1e-12
            I[i] = fsolve(diode_eq, I0, args=(v))[0]
    return I

# 3. Modeli me efekt prishjeje (Zener-like)
def I_with_breakdown(V, Vz=-0.7):
    I = I_shockley(V)
    breakdown_region = V < Vz
    I[breakdown_region] = -1e-3 * np.exp(-(V[breakdown_region] - Vz) / (0.02))
    I[I < -Iz_max] = -Iz_max
    return I

# Llogaritjet
I_ideal = I_shockley(V)
I_Rs = I_with_Rs(V, Rs=Rs)
I_break = I_with_breakdown(V)

# Vizatim
plt.figure(figsize=(8, 6))
plt.plot(V, I_ideal * 1e3, '-b', lw=3, label="Shockley Ideal")
plt.plot(V, I_Rs * 1e3, '--c', lw=2, label=f"Me Rezistencë në Seri (Rs={Rs}Ω)")
plt.plot(V, I_break * 1e3, '-.r', lw=2, label="Me Efekt Breakdown (psh. Zener)")
plt.axhline(0, color='black', lw=1)
plt.axvline(0, color='black', lw=1)
plt.xlabel("Tensioni $V_D$ (V)")
plt.ylabel("Rryma $I_D$ (mA)")
plt.title("Modele të Zgjeruara të Ligjit të Shockley për Dioda")
plt.grid(True)
plt.legend()
plt.ylim(-40, 60)
plt.xlim(-1.0, 1.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Diodat më të Rëndësishme dhe Fizika e Tyre
#
# | Dioda         | Struktura | Doping-u | Karakteristika | V–I karakteristikë (grafiku) |
# |---------------|-----------|----------|----------------|------------------------------|
# | **1N4148**    | Silic p–n | moderuar | Komutim i shpejtë, tension ~0.7 V | Rritje eksponenciale në forward, bllokim në reverse |
# | **Zener**| p–n shumë i dopuar | shumë i lartë | Prishje e qëndrueshme në polarizim të kundërt | Prishje në tensionin Zener, e përdorur për stabilizim tensioni |
# | **LED (e kuqe)** | p–n me GaAs | band gap direkt ~1.9 eV | Emeton dritë në rekombinim, tension përpara ~1.8–2.2 V | V–I e ngjashme me diodën p–n por tension më i lartë |
# | **Schottky**  | Metal–n | pa p-rajone | Barrierë më e ulët, komutim shumë i shpejtë | Rënie e vogël në tension (0.2–0.4 V), prishje më e hershme në reverse |
# | **Tunnel**    | p–n shumë i dopuar | ekstremisht i lartë | Tunelim kuantik, rajon me rezistencë negative | Kurba jo-monotone me kulm në rrymë dhe pastaj rënie |
#
#
# ## 4. Grafikët e Karakteristikës V–I
#
# Në grafikun që ke parë më sipër, shfaqen këto tipare **(shiko figurën më poshtë)**:
#
# - **1N4148 (silic)**: rënie tipike ~0.7 V, rritje eksponenciale.
# - **Zener**: sillet si diodë normale përpara, por në polarizim të kundërt ka një pikë “prishjeje” të kontrolluar (~5.1 V).
# - **LED (e kuqe)**: rënie më e lartë në tension përpara, pasi materiali ka band gap më të madh (shih GaAs).
# - **Schottky**: tension përpara më i vogël (~0.3 V), ideale për efikasitet të lartë.
# - **Tunnel diode**: ka një **rajon me rezistencë negative** në forward bias, ku rryma bie me rritjen e tensionit (veçori e unike).

# %%
import numpy as np
import matplotlib.pyplot as plt

# Tensionet përkatëse për çdo diodë
V = np.linspace(-1.5, 1.5, 400)

# Karakteristika V-I për dioda të ndryshme
def diode_iv(V, Is=1e-12, n=1, VT=0.025):
    return Is * (np.exp(V / (n * VT)) - 1)

# Parametra për disa lloje diodash
curves = {
    "Silicon (1N4148)": {"Is": 1e-12, "n": 1, 'col':'k'},
    "Zener 5.1V": {"Is": 1e-12, "n": 1, 'col':'b'},
    "LED (red)": {"Is": 1e-12, "n": 2, 'col':'r'},
    "Schottky": {"Is": 1e-10, "n": 1, 'col':'g'},
    "Tunnel": None  # trajtohet veçmas më poshtë
}

# Inicializimi i figurës
plt.figure(figsize=(10, 6))

# Vizato të gjitha karakteristikat përveç tunnel
for label, params in curves.items():
    if params is not None:
        I = diode_iv(V, Is=params["Is"], n=params["n"])
        plt.plot(V, I*1e3, lw=2, color=params["col"], label=label)  # rryma në mA

# Dioda Tunnel (me rezistencë negative)
V_tunnel = np.linspace(-0.6, 0.6, 400)
I_tunnel = 20 * (V_tunnel * np.exp(-100 * (V_tunnel - 0.1)**2))
plt.plot(V_tunnel, I_tunnel, '--c', lw=4, label="Diode Tunel")

# Përshtatje vizuale
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title("Karakteristikat V-I për Dioda të Ndryshme")
plt.xlabel("Tensioni (V)")
plt.ylabel("Rryma (mA)")
plt.grid(True)
plt.legend()
plt.ylim(-5, 30)
plt.xlim(-1.5, 1.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# <br>
# <br>
#
# <div style="border:5px solid #0a0; background-color:#ca0; color:#003; border-radius: 15px; padding: 10px;">
#
# ### Perkufizim
#
# **Clipper** në elektronikë, njihet një qark i cili limiton tensionin e sinjalit hyrës nga lart ose nga poshtë ose nga të dyja anët njëherazi. Me pak fjalë është një qark që "e pret valën" hyrëse nëse tensioni rritet mbi ose bie nën një tension të dhënë (jo domosdoshmërisht simetrik nga lart dhe poshtë).
#
# ---
#
# **Clamper** në elektronikë, njihet një qark i cili zhvendos sinjalin hyrës duke i shtuar një vlerë pozitive ose negative tensioni DC. Pra ndryshon "signal baseline" apo i jep një "offset voltage".
#
# </div>
#
# <br>
# <br>
#
# ## Lloje të ndryshme diodash dhe karakteristikat e tyre
#
#
# | **Lloji i Diodës** | **Përdorimi Kryesor** | **Parametrat Kryesorë** |
# |--------------------|------------------------|--------------------------|
# | **Diodë Silici sinjal vogël** (*1N4148*) | Sinjale digjitale, komutim i shpejtë, "cliping & clamping" | $V_{f}$ ≈ 0.7 V, $I_{max}$ ≈ 300 mA, $t_{switch}$ < 4 ns |
# | **Diodë Rektifikuese** (*1N4001–1N4007*) | Rektifikimi AC/DC në furnizime me energji elektrike |  $V_{f}$ ≈ 0.7 V, $I_{avg}$ ≈ 1 A, $V_{RRM}$ = 50–1000 V |
# | **Diodë Zener** (*1N4733A–1N4764A*) | Rregullim tensioni, mbrojtje kundër overvoltage |$V_Z$ = 3.3–75 V, $P_{max}$ = 0.5–5 W, $I_Z$ = sipas aplikimit |
# | **Diodë LED** | Emetim drite (indikatorë, ndriçim, sinjalizim) | $V_{f}$ ≈ 1.8–3.5 V (varet nga ngjyra), $I_{typ}$ ≈ 10–30 mA, $\lambda$ (gjatësia valore e dritës) |
# | **Diodë Schottky** (*1N5817–1N5819*) | Rektifikim me efikasitet të lartë, frekuencë të lartë | $V_{f}$ ≈ 0.2–0.4 V, $I_{avg}$ ≈ 1–3 A, $t_{switch}$ < 100 ns |
# | **Fotodiodë** | Detektim i dritës, sensorë optikë, fibra optike | $I_{photo}$ për një fluks drite të caktuar, $t_{response}$, $\lambda$ i ndjeshmërisë |
# | **Diodë Varaktor** (*Varicap*) | Kapacitet i rregullueshëm për frekuencë (tuning RF) |$C(V)$ ≈ 5–100 pF, $V_{reverse}$ = 1–30 V, $Q$ i lartë (cilësi në RF) |
# | **Diodë Tunnel** | Oshilatorë me frekuencë shumë të lartë, kërkime | $V_{peak}$, $V_{valley}$, Rajon me rezistencë negative, $I_{peak}$, $I_{valley}$ |
# | **Diodë PIN** | Komutim në RF, fotodetektorë të ndjeshëm | Kapacitet i ulët, Shpejtësi e lartë, Tension i lartë reverse |
# | **Diodë TVS** | Mbrojtje nga tensione transiente (ESD, “spikes”) | $V_{clamp}$, $P_{peak}$, $t_{response}$ < 1 ns |
#
#
# ## 5. Këshilla Si Të Projektojmë Qarqe me Dioda
#
# 1. **Njih tensionin prag ($V_f$)** "forward" – për silicin është 0.7 V, për Schottky më pak (~0.2V), për LED varet nga ngjyra.
# 2. **Kujdes me rrymën maksimale ($I_{\rm max}$)** "forward" – shiko fletën e të dhënave (datasheet), përdor rezistencë kufizuese kur nevojitet (p.sh. LED).
# 3. **Zgjidh Schottky për komutim të shpejtë ose tension të ulët**.
# 4. **Zener për stabilizim ose mbrojtje (clamping) në tension të caktuar**.
# 5. **Tunnel për oshilatorë në mikrorrymë – kujdes sepse nuk sillet si diodë normale**.
# 6. **LED = emetues → kujdes për polaritetin, dhe përdor rezistencë kufizuese për të shmangur dëmtimin**.
#
#
# ## Përmbledhje e Përgjithshme:
#
# - **Nëse do drejtim rryme të thjeshtë dhe të shpejtë:** përdor **1N4148**
# - **Për rektifikim të fuqishëm në furnizim elektrik:** **1N400x**
# - **Për stabilizim tensioni:** **Zener**
# - **Për sinjal ndriçues:** **LED**
# - **Për efikasitet dhe frekuencë të lartë:** **Schottky**
# - **Për sensorë drite:** **Fotodiodë**
# - **Për tuning në frekuenca RF:** **Varaktor**
# - **Për oshilatorë të avancuar:** **Tunnel diode**
# - **Për mbrojtje kundër transienteve:** **TVS diode**
#
#
# <br>
# <br>
#
# # **Aplikime**
#
# ## 1. **Clipper me diodë sinjali te vogël (1N4148)**
#
# **Qëllimi:** të presë (klipojë) tensionin në një nivel të caktuar për të mbrojtur komponentët e ndjeshëm.
#
# <img src="figs/lec6/clipper.svg" height="100" style="background-color:#fff;" >
#
# - **D = 1N4148**
# - Përdorim: mbrojtje e hyrjeve digjitale nga tejkalimi i tensionit maksimal.
#
#
# ## 2. **Rregullator tensioni me Zener**
#
# **Qëllimi:** të mbajë një tension të qëndrueshëm në dalje pavarësisht nga variacionet në hyrje.
#
# <img src="figs/lec6/V_regulator.svg" height="100" style="background-color:#fff;" >
#
# - **D = Zener 5.1 V**
# - Kur Vin > 5.1 V, dioda Zener hyn në breakdown dhe tensioni në dalje ngel 5.1 V.
#
#
# ## 3. **Indikator me LED**
#
# **Qëllimi:** të ndriçojë një LED për të treguar nëse një qark është i aktivizuar.
#
# <img src="figs/lec6/LED.svg" height="100" style="background-color:#fff;" >
#
# - **LED** për dritë.
# - **R** për të kufizuar rrymën në 10–20 mA.
#
#
# ## 4. **Rektifikues me Schottky për efikasitet**
#
# **Qëllimi:** të konvertojë sinjalin AC në DC me humbje të vogla.
#
# <img src="figs/lec6/schottky.svg" height="100" style="background-color:#fff;" >
#
# - **Schottky (1N5819)**
# - Rënia e tensionit në diodë është vetëm 0.3 V → më shumë fuqi në ngarkesë ($R_{\rm load}$).
#
#
# ## 5. **Mbrojtje nga transiente me TVS**
#
# **Qëllimi:** të mbrojë qarkun nga goditje të menjëhershme të tensionit (p.sh. ESD, spike).
#
# <img src="figs/lec6/TVS.svg" height="100" style="background-color:#fff;" >
#
#
# - **TVS diode (e polarizuar në drejtim të kundërt)**
# - Aktivizohet menjëherë kur tensioni tejkalon një vlerë dhe mbron qarkun.

# %% [markdown]
# <br>
# <br>
#
# ## 1. **Si modelohet një diodë në praktikë?**
#
# ### a) **Modeli ideal** (për analizë konceptuale)
#
# Dioda sillet si:
# - **Përçues perfekt** kur është në **forward bias** dhe $V_D > 0$.
# - **Izolues perfekt** në **reverse bias**, kur $V_D < 0$.
#
# $$
# I = \begin{cases}
# \text{përcjell çfarëdo rryme} & V_D > 0 \\
# 0 & V_D \leq 0
# \end{cases}
# $$
#
# ### b) **Modeli me prag (threshold model)**
#
# Përdor një **tension të fiksuar të përçueshmërisë**, p.sh. $V_\text{on} = 0.7\ \text{V}$ për silic dhe $V_\text{on} = 0.3\ \text{V}$ për germanium:
#
# - Kur $V_D < V_\text{on}$ → dioda është e mbyllur (dioda modelohet si qark i hapur).
# - Kur $V_D \geq V_\text{on}$ → dioda hapet dhe sillet si përçues (me rënie tensioni fikse 0.7 V). Dioda modelohet si thjeshte nje percjelles por me nje renie potenciali $V_\text{on}$.
#
#  **Modeli i përdorur në shumicën e analizave manuale** (analizë DC, qark klasik, clipper, rregullator, etj.)
#
#
#
# ### c) **Modeli eksponencial (Shockley model)**
#
# $$
# I_D = I_S \left( e^{\frac{V_D}{n V_T}} - 1 \right)
# $$
#
# ku:
# - $I_S$ = rryma e ngopjes (e vogël, zakonisht $\sim 10^{-12}$ A).
# - $V_T$ = tensioni termik ($\approx 25.9$ mV në $25^\circ$C).
# - $n$ = faktori idealitetit (1–2).
#
# **Ky model përdoret në simulime numerike si SPICE.** Jep sjellje shumë të saktë për tensionin dhe rrymën.
#
#
# ### d) **Modeli i qarkut me sinjale të vogla**
#
# Përdoret për **analiza sinjalesh të vogjel rreth pikës së punës DC**.
#
# - Supozohet një **rezistencë dinamike**:
#
# $$ r_d = \frac{n V_T}{I_D} $$
#
# - Modelet përfshijnë ndonjëherë edhe **kapacitete nyje** ($C_j$) dhe **rezistencë në seri $R_s$** (sic shpjeguam me lart).
#
#
# ## 2. **Si analizohen diodat në qark?**
#
# ### Metoda klasike: **Supozo dhe verifiko**
#
# 1. Supozojmë që dioda është **hapur (on)** ose **mbyllur (off)**.
# 2. Zëvendësojmë diodën në qark:
#    - **Hapur** → zëvendësohet me nje **burim rënës tensioni** (psh 0.7 V për silicin).
#    - **Mbyllur** → zëvendësohet me **qark të hapur**.
# 3. Zbatojmë **ligjin e Ohm-it, Kirchoff-it** për të gjetur rrymën.
# 4. **Verifikojmë** nëse supozimi është i vlefshëm:
#    - Nëse dioda supozohet e hapur dhe rryma del negative → supozimi gabim → është e mbyllur.
#    - Nëse supozohet ishte i mbyllur dhe tensioni del $>0.7$ V → gabim → është hapur.
#
#
#
# ### Shembull 1: Diodë me rezistencë dhe burim tensioni
#
# ```
# (Vin) ──►─|>|─── R ──── GND
# ```
#
# - P.sh. Vin = 5V, R = 1kΩ
# - Supozojmë që dioda është **hapur** ⇒ ka rënie 0.7V ⇒ tension në rezistencë: $5V - 0.7V = 4.3V$
# - Rryma: $I = 4.3V / 1k\Omega = 4.3$ mA
# - Rryma është pozitive ⇒ supozimi është i saktë.
#
#
# ### Shembull 2: Diodë clipper
#
# ```
# Sinjal AC ──►─|>|─── GND
#                D
# ```
#
# - Kur sinjali është pozitiv dhe > 0.7 V, dioda **hapet** dhe tensioni klipohet në 0.7 V.
# - Kur sinjali është negativ, dioda **mbetet e mbyllur**, tensioni shkon drejt vlerës së sinjalit.
#
#
# ## 3. Modelet në SPICE (p.sh. Ngspice)
#
# Në SPICE, përdoret modeli **Shockley** me shumë parametra realë të përfshirë:
#
# ```
# .model Dsil D(IS=1e-14 N=1 Rs=0.5 Cjo=2p Vj=0.7 M=0.5)
# ```
#
# Përdorimi në qark (netlist):
#
# ```
# V1 in 0 DC 5
# R1 in out 1k
# D1 out 0 Dsil
# ```
#
# > Kjo analizon tensionin dhe rrymën realisht, duke marrë parasysh edhe temperaturën, kapacitetin, rezistencën e brendshme, etj.
#
# ---
#
# ## 4. Grafikët V–I për modele të ndryshme
#
# | Modeli         | Avantazhi                      | Kufizimi                  |
# |----------------|-------------------------------|---------------------------|
# | Ideal          | Shumë i thjeshtë për analizë  | Jo realist                |
# | Me prag        | I thjeshtë, praktik            | Nuk reflekton rritjen reale të rrymës |
# | Eksponencial   | I saktë, realist               | Kompleks për analizë manuale |
# | Qark i vogël AC| Perfekt për sinjale të vogla   | Nuk vlen për sinjale të mëdha |
#
#
#
# ## Përmbledhje
#
# Për të dizajnuar dhe analizuar qarqe me dioda, duhet:
#
# 1. Të **kuptosh modelin fizik** dhe **kurbën V–I**.
# 2. Të **përdorësh modele të përshtatura** për analizë manuale (prag), numerike (eksponencial), apo dinamike (qark AC).
# 3. Të **zgjidhësh llojin e analizës** në varësi të sinjalit: DC, AC të vogël, ose tranzient.
# 4. Të **verifikosh supozimet me tension/rrymë** për të konfirmuar nëse një diodë është hapur apo mbyllur.

# %% [markdown]
# <br>
# <br>
#
# # Shembuj zbatimi të Diodave
#
# ### Zbritës Tensioni (voltage droper)
#
# Sic kemi thënë më lart, kur mbi diodë kalon rrymë krijohet një **"rënie tensioni"** (diferencë potenciale) mbi të.
# - Për një diodë silici p–n, kjo rënie është rreth **0.6-0.7 V**.
# - Për diodat gjermaniumi është rreth **0.2 V**.
# - Për diodat Schottky është rreth **0.4 V**.
#
# (**Shënim: Vlera e sakta të tensionit ndryshojnë pak në varësi të tipit të diodës**.)
#
# <img src="figs/lec6/DC_V_drop.svg" height="100" style="background-color:#fff;" >
#
# Nëse vendosim **shumë dioda në seri**, **rëniet e tensionit shtohen**:
# $$
# V_{\text{total}} = \sum V_{\text{diodave}}
# $$
#
# Ky fenomen përdoret për të ndërtuar **zbritës tensioni** (“voltage droppers”) në qarqe ku kërkohet një **diferencë e vogël dhe fikse tensioni** midis dy pjesëve.
#
# Ndryshe nga rezistencat (që gjithashtu mund të ulin tensionin), përdorimi i diodave:
# - **Harxhon më pak energji në nxehtësi**,
# - **Siguron një tension më të qëndrueshëm**, më pak të varur nga ndryshimet në rrymë.
#
# **Shënim:** Lidhja në seri e disa diodave në polaritet të drejtë mund të zëvëndësohet me **një diodë Zener** per të arritur të njëjtin efekt të rënies së tensionit.
#
# <br>
#
# ## Mbrojtja nga Transienteve me Dioda Fly-Back
#
# Kur rryma që kalon përmes një bobine ndryshon shpejt, fusha magnetike përkatëse gjeneron një **ndryshim të madh të tensionit** ("voltage spikes" apo transient), që mund të jenë shumë të dëmshme për komponentet apo qarqet që lidhen me bobinën.
#
# - Këto transiente mund të kenë amplituda prej **qindra ose mijëra voltësh**.
# - Fenomeni është **veçanërisht i zakonshëm në bobinat e releve**.
#
# Për të mbrojtur qarkun:
# - Përdoret një **diodë**, e quajtur **diodë fly-back**, e cila vendoset **paralelisht me bobinën e relesë**.
# - Kjo diodë **krijon një qark të shkurtër** për transient të tensionit dhe e humb energjinë në mënyrë të sigurtë.
#
# Përveç mbrojtjes së qarqeve elektronike, dioda **mbron edhe kontaktet mekanike** të relesë nga goditjet e forta që shkaktohen gjatë këtyre spikave.
#
# <img src="figs/lec6/transient1.png" height="100" style="background-color:#fff;" > <img src="figs/lec6/transient2.png" height="100" style="background-color:#fff;" >
#
# #### Mrojtja Induktive nga një Motor (Inductive Kickback)
#
# Një motor që është në punë dhe fiket papritur, mund të gjenerojë një tension transient të rrezikshëm që mund të dëmtojë komponentët elektronikë të lidhur me të.
#
# <img src="figs/lec6/transient3.png" height="100" style="background-color:#fff;" >
#
#
# <br>
#
# ### Diodat kufizuese (clipper diode)
#
# Në qarkun e një **kufizuesi me përshtatje**, **niveli maksimal i daljes** kufizohet në një vlerë që përcaktohet nga **rezistenca e një potenciometri**.
#
# **Ideja themelore:**
# - **Anoda e diodës** lidhet me daljen e sinjalit,
# - **Katoda e diodës** lidhet me një tension të përcaktuar përmes potenciometrit,
# - Ky tension duhet të jetë rreth **0.6 V më i ulët** se niveli maksimal i dëshiruar i daljes,
#   që të kompensohet **rënie e tensionit përpara** për diodën (rreth 0.6 V për silic).
#
# **Roli i potenciometrit:**
# - Përshtat tensionin në anën negative të diodës, duke përcaktuar pikën ku fillon kufizimi.
#
# **Kërkesë shtesë:**
# - Tensioni +V që furnizon qarkun duhet të jetë **rreth 1 V më i lartë** se tensioni maksimal i sinjalit hyrës, për të garantuar që dioda të punojë siç duhet në rajonin e përcjelljes.
#
# <img src="figs/lec6/clipper1.png" height="100" style="background-color:#fff;" >
#
# <img src="figs/lec6/clipper2.png" height="100" style="background-color:#fff;" >
#
#
# <br>
#
# ### Diode Clamping
#
# <img src="figs/lec6/clamp1.png" height="100" style="background-color:#fff;" >
# <img src="figs/lec6/clamp2.png" height="100" style="background-color:#fff;" >
#
#
# ### Radrizimi (Diode Rectifier)
#
# <img src="figs/lec6/rectifier.png" height="100" style="background-color:#fff;" >
# <img src="figs/lec6/rectifier2.png" height="100" style="background-color:#fff;" >
#
#
# ### Shumëzuesit e Tensionit (Voltage Multipliers)
#
# <img src="figs/lec6/multiplier.png" height="100" style="background-color:#fff;" >
# <img src="figs/lec6/multiplier2.png" height="100" style="background-color:#fff;" >
#
#
# ### Porta Logjike me Dioda
#
# <img src="figs/lec6/logicalGate.png" height="100" style="background-color:#fff;" >
#
#
# ### Voltmetër i Thjeshtë me LED
#
# <img src="figs/lec6/Voltmeter.png" height="100" style="background-color:#fff;" >
#
# <br>

# %% [markdown]
# <br>
# <br>
#
# # **Ushtrime Praktike në Laborator**
#
# **Laboratori: Eksperimente Themelore me Dioda**
#
# ## Ushtrimi 1: Matja e Karakteristikës V-I të Diodës
#
# **Komponentët dhe Pajisjet:**
# - Diodë silici 1N4148
# - Rezistencë 1 kΩ
# - Furnizim DC i rregullueshëm (0—1.5 V)
# - 2 multimetra ose osciloskop
#
# **Skema e qarkut:**
# ```
# Vdc ─── R ───|>|─── GND
# ```
#
# **Procedura:**
# 1. Lidheni qarkun sipas skemës.
# 2. Rritni gradualisht tensionin nga 0 V deri në 1.5 V.
# 3. Matni rrymën (nga tensioni mbi rezistencë) dhe tensionin mbi diodën.
# 4. Vizato grafikisht $V_D$ kundrejt $I_D$.
#
# **Pyetje:**
# - Në çfarë vlere të tensionit fillon dioda të përçjellë?
# - A sillet qarku sipas ligjit të Shockley?
#
#
#
# ## Ushtrimi 2: Diodë Clipper
#
# **Komponentët dhe Pajisjet:**
# - Diodë 1N4148
# - Rezistencë 1 kΩ
# - Gjenerator funksioni (sinus 10 Vpp, 1 kHz)
# - Osciloskop 2-kanalësh
#
# **Skema e qarkut:**
# ```
# Vin ~ ──+---|>|── GND
#          |
#          +--- R --- Vout
# ```
#
# **Procedura:**
# 1. Apliko sinjal sinusoidal nga gjeneratori funksioneve.
# 2. Mat sinjalin në hyrje dhe dalje me osciloskop.
# 3. Vëre ku dioda fillon të presë sinjalin.
#
# **Eksploroni:**
# - Ndrysho drejtimin e diodës.
# - Shto burim DC në seri për të ndryshuar pikën e cliping.
#
# **Pyetje:**
# - Si sillet forma e sinjalit?
# - Përse quhet klipper?
#
#
#
# ## Ushtrimi 3: Stabilizator me Zener
#
# **Komponentët dhe Pajisjet:**
# - Diodë Zener (psh 5.1 V)
# - Rezistencë 470 Ω – 1 kΩ
# - Furnizim DC 0—12 V
# - Osciloskop ose voltmetër
#
# **Skema e qarkut:**
# ```
# Vin ── R ──+--- Vout
#              |
#            [Zener]
#              |
#             GND
# ```
#
# **Procedura:**
# 1. Rrit Vin nga 0 deri në 12 V.
# 2. Mat Vout.
# 3. Vëre ndryshimin e Vout kur Vin > 5.1 V (tensionin që ka dioda zener që keni zgjedhur).
#
# **Pyetje:**
# - Përse Zener mban tension konstant?
# - Si ndikon vlera e rezistencës?
#
#
#
# ## Ushtrimi 4: Rektifikimi (drejtimi) me një Diodë të Vetme
#
# **Komponentët dhe Pajisjet:**
# - Diodë 1N4007
# - Rezistencë 1 kΩ
# - Gjenerator funksioni
# - Osciloskop
#
# **Skema e qarkut:**
# ```
# AC ~ ──|>|──+--- R --- GND
#                |
#               Vout
# ```
#
# **Procedura:**
# 1. Apliko sinjal AC.
# 2. Vëre formën e sinjalit në dalje.
# 3. Analizo gjysmë-periodën aktive.
#
# **Pyetje:**
# - Përse gjysma negative mungon?
# - Çfarë ndodh nëse shtojmë kondensator?
#
#
#
# ## Ushtrimi 5: Mbrojtja nga mbi-voltazhi me Zener
#
# **Komponentët dhe Pajisjet:**
# - Diodë Zener
# - Rezistencë
# - Burim tensioni DC
# - Oshiloskop
#
# **Skema e qarkut:**
# ```
# Vin ──+---- Vout
#        |
#      [Zener]
#        |
#       GND
# ```
#
# **Procedura:**
# 1. Apliko tension të ndryshueshëm.
# 2. Shiko kur Zener fillon të bllokojë rritjen e Vout.
# 3. Vizato Vout kundrejt Vin.
#
# **Pyetje:**
# - Kur aktivizohet Zener?
# - Si ndihmon kjo skemë në mbrojtjen e qarqeve?
#
#
#
# ## **Detyrë Shtesë:**
# Zbatoni për secilën qark simulimin në software si Falstad apo LTspice/Ngspice dhe krahasojeni me rezultatet eksperimentale.
