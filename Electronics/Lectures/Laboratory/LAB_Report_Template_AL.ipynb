# %%
# Kjo qelize rregullon pamjen vizuale te raportit.
# Mos e ndrysho!

from IPython.display import display, HTML

display(HTML("""
<style>

.jp-RenderedMarkdown {
    font-family: "Segoe UI", Roboto, sans-serif;
    line-height: 1.6;
}

.jp-RenderedMarkdown h1 {
    text-align: center;
    border-bottom: 3px solid #222;
    padding-bottom: 0.4em;
    margin-top: 0.5em;
}

.jp-RenderedMarkdown h2 {
    border-left: 6px solid #444;
    padding-left: 0.6em;
    margin-top: 1.8em;
}

.jp-RenderedMarkdown h3 {
    margin-top: 1.2em;
    font-weight: 600;
}

table {
    border-collapse: collapse;
}

th, td {
    border: 1px solid #aaa;
    padding: 6px 10px;
}

</style>
"""))
# Out:
# <style>
#
# .jp-RenderedMarkdown {
#     font-family: "Segoe UI", Roboto, sans-serif;
#     line-height: 1.6;
# }
#
# .jp-RenderedMarkdown h1 {
#     text-align: center;
#     border-bottom: 3px solid #222;
#     padding-bottom: 0.4em;
#     margin-top: 0.5em;
# }
#
# .jp-RenderedMarkdown h2 {
#     border-left: 6px solid #444;
#     padding-left: 0.6em;
#     margin-top: 1.8em;
# }
#
# .jp-RenderedMarkdown h3 {
#     margin-top: 1.2em;
#     font-weight: 600;
# }
#
# table {
#     border-collapse: collapse;
# }
#
# th, td {
#     border: 1px solid #aaa;
#     padding: 6px 10px;
# }
#
# </style>

# %% [markdown]
# <div style="text-align:center">
#
# # Raport Laboratori – Elektronikë
# ## Titulli i Eksperimentit: ___________________________
#
# **Lënda:** Hyrje në Elektronikë (Viti III, Fizikë)
# **Pedagogu:** ___________________________
# **Student(ët):** ___________________________
# **Grupi:** ___________________________
# **Data e zhvillimit:** ___________________________
# **Data e dorëzimit:** ___________________________
#
# </div>
#
# ---

# %% [markdown]
# # 1. Qëllimi i Eksperimentit
#
# Përshkruani qartë qëllimin e këtij eksperimenti.
#
# - Cili qark/sistem analizohet?
# - Cili parim fizik verifikohet?
# - Cili parametër përcaktohet?
# - Cila marrëdhënie teorike testohet?
#
# (4–6 fjali teknike dhe koncize)

# %% [markdown]
# # 2. Baza Teorike
#
# ## 2.1 Modeli i Qarkut
#
# Vendosni skemën elektrike ose fotografi të qarkut.
#
# Përcaktoni:
# - Sinjalin hyrës $V_{in}$
# - Sinjalin dalës $V_{out}$
# - Vlerat e komponentëve
# - Supozimet (komponentë idealë, regjim linear, etj.)

# %% [markdown]
# ## 2.2 Ekuacionet Themelore
#
# Paraqisni derivimet kur kërkohet.
#
# Shembull:
#
# $$
# H(j\omega) = \frac{V_{out}}{V_{in}}
# $$
#
# Llogaritni vlerën teorike:
#
# $$
# f_{teori} = \_\_\_\_\_
# $$

# %% [markdown]
# # 3. Ndërtimi Eksperimental
#
# ## 3.1 Pajisjet
#
# | Pajisja | Modeli | Diapazoni | Saktësia |
# |----------|--------|-----------|-----------|
# | Oskiloskop | | | |
# | Gjenerator funksionesh | | | |
# | Multimetër | | | |
#
# ## 3.2 Montimi Praktik
#
# Vendosni foto ose skemë të montimit real.
#
# Specifikoni:
# - Amplitudën e sinjalit
# - Faktorin e sondës (1x / 10x)
# - Referencën e tokëzimit
# - Vlerat nominale dhe tolerancat e komponentëve

# %% [markdown]
# # 4. Të Dhënat e Matura

# %%
import pandas as pd

data = pd.DataFrame({
    "Frekuenca (Hz)": [],
    "Vin (Vpp)": [],
    "Vout (Vpp)": []
})

data
# Out:
# Empty DataFrame
# Columns: [Frekuenca (Hz), Vin (Vpp), Vout (Vpp)]
# Index: []

# %%
data["Amplifikimi"] = data["Vout (Vpp)"] / data["Vin (Vpp)"]
data
# Out:
# Empty DataFrame
# Columns: [Frekuenca (Hz), Vin (Vpp), Vout (Vpp), Amplifikimi]
# Index: []

# %% [markdown]
# # 5. Analiza e të Dhënave

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(6,4))
plt.semilogx(data["Frekuenca (Hz)"], 20*np.log10(data["Amplifikimi"]))
plt.xlabel("Frekuenca (Hz)")
plt.ylabel("Amplifikimi (dB)")
plt.title("Grafiku Bode (Amplituda)")
plt.grid(True, which="both")
plt.show()

# %% [markdown]
# Nga grafiku përcaktoni:
#
# - Frekuencën e prerjes (eksperimentale)
# - Pjerrësinë pas frekuencës së prerjes
# - Krahasimin me vlerën teorike

# %% [markdown]
# # 6. Analiza e Gabimive
#
# Llogaritni gabimin relativ:
#
# $$
# \text{Gabimi} = \frac{|f_{exp} - f_{teori}|}{f_{teori}} \times 100\%
# $$
#
# Diskutoni në mënyrë sasiore:
#
# - Tolerancat e komponentëve
# - Pasiguritë e matjes
# - Kufizimet e instrumenteve
# - Efektet parazitare

# %% [markdown]
# # 7. Diskutimi
#
# Jepni analizë fizike:
#
# 1. Shpjegoni sjelljen e vëzhguar të qarkut.
# 2. Identifikoni burimet kryesore të devijimit nga pritshmëritë.
# 3. Propozoni përmirësime konkrete të eksperimentit.

# %% [markdown]
# # 8. Përfundimi
#
# Paraqisni në mënyrë sasiore:
#
# - Vlerën teorike
# - Vlerën eksperimentale
# - Devijimin në përqindje
# - Përfundimet tuaja
#
# (Maksimumi 6 fjali të qarta dhe koncize)
